# %% [markdown]
# # CH03 Python 的数据结构、函数和文件

# %% [markdown]
# ### 3.1数据结构和序列
# * 元组
# 固定长度，不可改变的序列对象
#
#
# 用逗号分隔一列值

# %%
tup=4,5,6
tup
# Out:
# (4, 5, 6)

# %% [markdown]
# 复杂的元组定义最好放到括号内

# %%
tup2=(4,5,6,7),(8,7,6,5)
tup2
# Out:
# ((4, 5, 6, 7), (8, 7, 6, 5))

# %% [markdown]
# tuple可以将任意序列或者迭代器转换为元组

# %%
tuple([1,4,7])
# Out:
# (1, 4, 7)

# %%
tup=tuple("string")
tup
# Out:
# ('s', 't', 'r', 'i', 'n', 'g')

# %% [markdown]
# * 使用方括号来访问元组中的元素

# %%
tup[0]
# Out:
# 's'

# %% [markdown]
# * 元组是不可修改的，但是如果元组对象是可变的，可以对元组对象进行修改。

# %%
tup=tuple(['11',[1,2]])

# %%
tup[2]=1
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# <ipython-input-18-71e3c26112c7> in <module>()
# ----> 1 tup[2]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup[1].append(3)
tup
# Out:
# ('11', [1, 2, 3])

# %%
tup
# Out:
# ('s', 't', 'r', 'i', 'n', 'g')

# %% [markdown]
# * 可以用+对元组进行相加，*对元组进行复制

# %%
(1,2,3)+(9,8,7)
# Out:
# (1, 2, 3, 9, 8, 7)

# %%
(4,5,6)*5
# Out:
# (4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6)

# %% [markdown]
# 元组的拆分赋值，这个特性可以用来替换变量名

# %%
tup=4,5,(6,7)
a,b,(c,d)=tup
d
# Out:
# 7

# %%
a,b=5,6
b,a=a,b
b
# Out:
# 5

# %% [markdown]
# 变量的拆分常用来迭代或者函数的返回值中使用。

# %% [markdown]
# * 高级用法 特殊的语法\*rest ,表示丢弃掉的部分，也常用\*_来表示

# %%
values = 1, 2, 3, 4, 5,2
a, b, *rest = values
b
# Out:
# 2

# %%
a, b, *_ = values
b
# Out:
# 2

# %% [markdown]
# * 方法
# 因为大小和内容不可修改的特性，方法都很轻量级
# 常用的一个是count

# %%
values.count(2)
# Out:
# 2

# %% [markdown]
# * 列表
# 使用频率最高，最灵活，长度内容均可变。
# 可以用方括号定义，也可以用list函数转换
# list函数常用来处理迭代器或者生成器

# %%
alist=[1,2,3,4,'wa',None]
alist
# Out:
# [1, 2, 3, 4, 'wa', None]

# %%
blist=list(values)
blist
# Out:
# [1, 2, 3, 4, 5, 2]

# %% [markdown]
# 添加元素append，
# 插入元素insert，这个操作性能消耗巨大，因为后面的引用都需要变
# 移除指定位置元素pop
# 移除某个值remove

# %%
alist.append(99)
alist
# Out:
# [1, 2, 3, 4, 'wa', None, 99]

# %%
alist.insert(1,999)
alist
# Out:
# [1, 999, 2, 3, 4, 'wa', None, 99]

# %%
alist.pop(1)
alist
# Out:
# [1, 2, 3, 4, 'wa', None, 99]

# %%
alist.remove(99)
alist
# Out:
# [1, 2, 3, 4, 'wa', None]

# %% [markdown]
# in 判断列表是否包含某个值，not in 不包含, 比字典和集合慢，字典和集合基于哈希表

# %%
99 in alist
# Out:
# False

# %%
99 not in alist
# Out:
# True

# %% [markdown]
# 使用+或者extend来连接两个列表，推荐使用extend

# %%
x=[1,2,3,4]
x.extend([9,8,7])
x
# Out:
# [1, 2, 3, 4, 9, 8, 7]

# %% [markdown]
# * 排序 sort
# 改变原列表
# sort还有一个二级排序key,很好用

# %%
x.sort()
x
# Out:
# [1, 2, 3, 4, 7, 8, 9]

# %%
b = ['saw', 'small', 'He', 'foxes', 'six']
b.sort(key=len)
b
# Out:
# ['He', 'saw', 'six', 'small', 'foxes']

# %% [markdown]
# bisect 二分查找插入
# bisect.bisect查找插入后任然有序的位置
# bisect.insort 向这个位置插入值
# 注意：列表必须的排好序的，不然虽然不会报错，但是结果肯定不对

# %%
 import bisect
 c = [1, 2, 2, 2, 3, 4, 7]
bisect.bisect(c, 2)
# Out:
# 4

# %%
bisect.insort(c, 5)
c
# Out:
# [1, 2, 2, 2, 3, 4, 5, 7]

# %% [markdown]
# 列表的切片这个也很好用，包括起始不包括结束

# %%
seq = [7, 2, 3, 7, 5, 6, 0, 1]
seq[1:5]
# Out:
# [2, 3, 7, 5]

# %%
seq[1:]
# Out:
# [2, 3, 7, 5, 6, 0, 1]

# %%
seq[:5]
# Out:
# [7, 2, 3, 7, 5]

# %% [markdown]
# 切片也可以赋值

# %%
seq[3:4]=["a","b"]
seq
# Out:
# [7, 2, 3, 'a', 'b', 5, 6, 0, 1]

# %% [markdown]
# 负数表示从后向前切片

# %%
seq[:-2]
# Out:
# [7, 2, 3, 'a', 'b', 5, 6]

# %% [markdown]
# 在第二个冒号可以使用step

# %%
seq[::2]
# Out:
# [7, 3, 'b', 6, 1]

# %% [markdown]
# 反转列表的写法

# %%
seq[::-1]
# Out:
# [1, 0, 6, 5, 'b', 'a', 3, 2, 7]

# %% [markdown]
# 序列函数
# enumerate 从序列中返回一个（i,value）

# %%
for i,value in enumerate(seq):
    print(i,value)
# Out:
# 0 7
# 1 2
# 2 3
# 3 a
# 4 b
# 5 5
# 6 6
# 7 0
# 8 1

# %% [markdown]
# sorted返回一个排好序的列表，和sort的区别就是不改变原列表，可以和sort传值一样

# %% [markdown]
# zip 拉链函数，这个也很好用跟scala里的一样用，将多个序列和一个元组对，以短的为准

# %%
seq1 = ['foo', 'bar', 'baz']
seq2 = ['one', 'two', 'three']
seq3 = [False, True]
list(zip(seq1, seq2, seq3))
# Out:
# [('foo', 'one', False), ('bar', 'two', True)]

# %% [markdown]
# zip常用来同时迭代多个序列

# %%
for i, (a, b) in enumerate(zip(seq1, seq2)):
    print('{0},{1},{2}'.format(i,a,b))
# Out:
# 0,foo,one
# 1,bar,two
# 2,baz,three

# %% [markdown]
# 高级用法，用\* 来解压序列

# %%
pitchers = [('Nolan', 'Ryan'), ('Roger', 'Clemens'),('Schilling', 'Curt')]
a,b=zip(*pitchers)

# %%
a
# Out:
# ('Nolan', 'Roger', 'Schilling')

# %%
b
# Out:
# ('Ryan', 'Clemens', 'Curt')

# %% [markdown]
# reversed函数
# reversed 可以从后向前迭代一个序列：
# 要记住 reversed 是一个生成器 ，只有实体化（即列表或for循
# 环） 之后才能创建翻转的序列。

# %%
list(reversed(range(10)))
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %% [markdown]
# * 字典
# 相当于java里的hashmap,kv对

# %%
d1 = {'a' : 'some value', 'b' : [1, 2, 3, 4]}
d1
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4]}

# %%
d1['name']='alex'
d1
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 'name': 'alex'}

# %%
d1['name']
# Out:
# 'alex'

# %%
'name' in d1
# Out:
# True

# %% [markdown]
# 使用del或pop来删除值，pop会返回删除的值
# keys()和values()是字典的键和值的迭代器方法

# %%
k1=list(d1.keys())
k1
# Out:
# ['a', 'b', 'name']

# %%
v1=list(d1.values())
v1
# Out:
# ['some value', [1, 2, 3, 4], 'alex']

# %% [markdown]
# update更新键值，改变原字典

# %% [markdown]
# 用序列创建字典dict

# %%
mapping={}
for k,v in zip(k1,v1):
    mapping[k]=v
mapping
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 'name': 'alex'}

# %%
dict(zip(k1,v1))
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 'name': 'alex'}

# %%
from collections import defaultdict
words = ['apple', 'bat', 'bar', 'atom', 'book']
by_letter = defaultdict(list)
by_letter
# Out:
# defaultdict(list, {})

# %%
for word in words:
    by_letter[word[0]].append(word)

# %%
by_letter
# Out:
# defaultdict(list, {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']})

# %% [markdown]
# * 集合（set）
# 无序的不可重复的元素的集合，是不可变的

# %%
a=set([1,2,22,22,2,3,3,5,4,5,1])
a
# Out:
# {1, 2, 3, 4, 5, 22}

# %% [markdown]
# 集合支持数学的集合运算
# 并集 union  |
# 交集 intersection &
# 差集 difference  -
# 常用的集合运算
# ![image.png](attachment:image.png)

# %%
a |{5,99,88,77}
# Out:
# {1, 2, 3, 4, 5, 22, 77, 88, 99}

# %%
a&{5,666,333}
# Out:
# {5}

# %%
a-{5,7}
# Out:
# {1, 2, 3, 4, 22}

# %% [markdown]
# 判断一个集合是否是另一个集合的子集或者父集
# issubset
# issupperset

# %%
a.issubset({1, 2, 3, 4, 5, 22,77})
# Out:
# True

# %% [markdown]
# * 列表、集合和字典推导式
# 列表推导式是python的重要特性，很方便,scala也有类似的特性

# %% [markdown]
# [expr for val in collection if condition]

# %%
strings = ['a', 'as', 'bat', 'car', 'dove', 'python']

# %%
[x.upper() for x in strings if len(x)>2]
# Out:
# ['BAT', 'CAR', 'DOVE', 'PYTHON']

# %% [markdown]
# 用相似的方法，还可以推导集合和字典。字典的推导式如下所示：
# dict_comp = {key-expr : value-expr for value in collection if condition}
# 集合的推导式与列表很像，只不过用的是尖括号：
# set_comp = {expr for value in collection if condition}

# %%
{len(x) for x in strings}
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# map 函数跟scala的一样，操作集合里面的每一个元素，用相同的函数

# %%
set(map(len,strings))
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# 嵌套列表推导式，相当于双重for循环

# %%
some_tuples = [(1, 2, 3), (4, 5, 6), (7, 8, 9)]
[x for temp in   some_tuples  for x in temp]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### 函数
# 用def 声明 用return返回

# %%
def my_fun(x,y,z=1.5):
    if z>1:
        return z*(x+y)
    else:
        return z/(x+y)

# %%
my_fun(1,2,1)
# Out:
# 0.3333333333333333

# %%
my_fun(1,2)
# Out:
# 4.5

# %% [markdown]
# * 命名空间、作用域，和局部函数
# 全局变量和局部变量，和java一样理解就可以。一个是整个程序生命周期都有效，一个是函数执行完毕后就失效。

# %%
a = []
def func():
    for i in range(5):
        a.append(i)

# %%
func()
a
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# * 返回多个值
# 和java不一样python可以返回多个值,实际上是元组，scala也可以

# %%
def fun2(x,y,z):
    return x+1,y+1,z+1

# %%
a,b,c=fun2(1,2,3)

# %%
a
# Out:
# 2

# %% [markdown]
# 可以将函数作为参数来进行传递
#
#     str.title 首字母大写

# %%
import re
def clean_strings(strings):
    result = []
    for value in strings:
        value = value.strip()
        value = re.sub('[!#?]', '', value)
        value = value.title()
        result.append(value)
    return result

# %%
states = ['   Alabama ', 'Georgia!', 'Georgia', 'georgia', 'FlOrIda',
          'south   carolina##', 'West virginia?']
clean_strings(states)
# Out:
# ['Alabama',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Florida',
#  'South   Carolina',
#  'West Virginia']

# %%
def remove_punctuation(val):
    return re.sub('[!#?]','',val)

# %% [markdown]
# re.sub的参数：有五个参数
#
# re.sub(pattern, repl, string, count=0, flags=0)
#
# pattern，表示正则中的模式字符串。
#
# repl，就是replacement，被替换，的字符串的意思。

# %%
clean_ops = [str.strip, remove_punctuation, str.title]

def clean_strings(strings, ops):
    result = []
    for value in strings:
        for function in ops:
            value = function(value)
        result.append(value)
    return result

# %% [markdown]
# 把函数当做参数传递

# %%
clean_strings(states, clean_ops)
# Out:
# ['Alabama',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Florida',
#  'South   Carolina',
#  'West Virginia']

# %%
for x in map(remove_punctuation,states):
    print(x.title())
# Out:
#    Alabama
# Georgia
# Georgia
# Georgia
# Florida
# South   Carolina
# West Virginia

# %% [markdown]
# * lambda函数
#
# 匿名函数，常用来作为临时的数据处理

# %%
test=lambda x: x*2

# %%
test(4)
# Out:
# 8

# %%
strings = ['foo', 'card', 'bar', 'aaaa', 'abab']

# %%
strings.sort(key=lambda x: len(list(x)))

# %%
strings
# Out:
# ['foo', 'bar', 'card', 'aaaa', 'abab']

# %% [markdown]
# * 函数的柯里化
#
# 实际就是把fun(x,y) 变成了fun(x)(y) 而已，是函数式编程必然会产生的东西

# %% [markdown]
# * 生成器
#
# 懒执行的，在函数里把return 换为yield 即可，跟scala很像

# %%
def squares(n=10):
    print('Generating squares from 1 to {0}'.format(n ** 2))
    for i in range(1, n + 1):
        yield i ** 2

# %%
gen=squares()

# %% [markdown]
# 调用的时候才会执行.

# %%
for x in gen:
    print(x)
# Out:
# Generating squares from 1 to 100
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# * 生成器表达式
#
# 把列表推导式的方括号换成圆括号

# %%
gen=(x*2 for x in range(100))

# %% [markdown]
# * itertools模块
# ![image.png](attachment:image.png)

# %%
import itertools

# %%
 names = ['Alan', 'Adam', 'Wes', 'Will', 'Albert', 'Steven']

# %% [markdown]
# 相邻的才会分到一组，分开了就重新分

# %%
import itertools
first_letter = lambda x: x[0]
names = ['Alan', 'Adam', 'Wes', 'Will', 'Albert', 'Steven','Will','Will']
for letter, names in itertools.groupby(names, first_letter):
    print(letter, list(names)) # names is a generator
# Out:
# A ['Alan', 'Adam']
# W ['Wes', 'Will']
# A ['Albert']
# S ['Steven']
# W ['Will', 'Will']

# %%
itertools.groupby(names, first_letter)

# %% [markdown]
# * 异常处理
#
# try except:  当try的部分抛出异常的时候才处理except的部分
#
# 跟java一样最后可以跟一个finally 来处理关闭连接等的任务

# %%
def  errfun(x):
    try:
        return float(x)
    except:
        return x
    finally:
        print("关闭")

# %%
errfun("紫福鸥")
# Out:
# 关闭
# '紫福鸥'

# %% [markdown]
# ### 3.3文件和OS

# %%
path='/data1/ai_proj/jupyter_proj/py4dataAnalysis2/Readme.md'

# %% [markdown]
# 默认情况下是以只读的模式打开的‘r’

# %%
f=open(path)

# %%
for line in f:
    print(line)
# Out:
# #  python数据分析第二版

# %% [markdown]
# 使用完毕一定记得关闭资源，

# %%
f.close()

# %% [markdown]
# 如果容易忘记关闭可以考虑用with，这样就不用关闭

# %%
with open(path) as f:
    lines=[x.rstrip() for x in f]

# %%
lines
# Out:
# ['', '#  python数据分析第二版', '', '']

# %% [markdown]
# 读写模式
# ![image.png](attachment:image.png)
#
# 向文件写入有write和writeline的方法。

# %%
with open('tmp.txt','w') as handle:
    handle.writelines(str(x) for x in range(100))

# %% [markdown]
# 常用的方法
# ![image.png](attachment:image.png)

# %% [markdown]
# * 编码和解码

# %%
with open(sink_path, 'xt', encoding='utf-8')as f：

# %% [raw]
# a
