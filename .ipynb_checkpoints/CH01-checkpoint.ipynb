# %% [markdown]
# #  Ch01 准备工作
# ###  1.1 本书内容
# ###  1.2为什么用python
# python 能干什么  各种库，框架，易用，胶水语言，这两年在数据科学机器学习学界工业界流行起来
# python不能干什么 需要高效的情况高并发的情况做不了，GIL全局解释器锁（Global Interpreter Lock，GIL），防止并行执行
# ### 1.3 重要的python库
# * NumPy 科学计算基础包
# * pandas 快速处理结构化数据，特别是里面的DF跟spark的很像
# * matplotlib 绘图和可视化
# * SciPy 科学计算包 包括微分方程求解，线性代数矩阵分解，信号处理，稀疏矩阵，离散概率分布
# * scikit-learn 机器学习包，
# ![image.png](attachment:image.png )
# * statsmodels 统计学习包
# ### 1.4 安装
# anaconda就可以，一站式解决方案
# ### 1.5 社区支持
# ### 1.6 本书导航
# 数据规整（Munge/Munging/Wrangling）：将散乱的数据、非结构化的数据处理为结构化数据的过程。
